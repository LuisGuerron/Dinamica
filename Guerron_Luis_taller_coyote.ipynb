# %%
"Un cuerpo cuadrado de b=3[m] de masa m=2000[kg] que pivota sobre la esquina (punto O). Suponga que la piedra rueda sin deslizar y que hay una fricción en la rueda con µ=0.3. Calcule: el ángulo al cual el cuerpo pierde contacto con la esquina (punto O) y empieza a caer,para esto, va a necesitar realizar un gráfico de la variación de la normal con respecto al ángulo de giro y también realice un gráfico de la variación de la velocidad angular hasta el mismo ángulo del literal anterior"
# Out:
# 'Un cuerpo cuadrado de b=3[m] de masa m=2000[kg] que pivota sobre la esquina (punto O). Suponga que la piedra rueda sin deslizar y que hay una fricción en la rueda con µ=0.3. Calcule: el ángulo al cual el cuerpo pierde contacto con la esquina (punto O) y empieza a caer,para esto, va a necesitar realizar un gráfico de la variación de la normal con respecto al ángulo de giro y también realice un gráfico de la variación de la velocidad angular hasta el mismo ángulo del literal anterior'

# %% [markdown]
# ![boulder.png](attachment:boulder.png)

# %% [markdown]
# ![Sol_Taller_Coyote.png](attachment:Sol_Taller_Coyote.png)
